# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
import datetime
#d = datetime.datetime.strptime('2011-06-09', '%Y-%m-%d')
#d.strftime('%b %d,%Y')


sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv(r"C:\Users/Hp/Desktop/challenge/trades.csv")
print("thetyperofdata is: ",data.shape,"\n")
print(data.head())

data.dropna()
plt.figure(figsize=(10, 4))
plt.title("IOTA/BTC")
plt.xlabel("timestamp")
plt.ylabel("price")
plt.plot(data["price"])
plt.show()


from autots import AutoTS
model = AutoTS(forecast_length=1, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col='timestamp', value_col='price', id_col=None)
 
prediction = model.predict()
forecast = prediction.forecast
print("IOTA/BTC .predict is ")
print(forecast)
# Out:
# thetyperofdata is:  (96503, 6)
#
#    Unnamed: 0                timestamp        id     price  side  amount
# 0           0  2020-07-17 00:01:10.647  19088200  0.000026   buy     4.0
# 1           1  2020-07-17 00:01:26.820  19088201  0.000026  sell    58.0
# 2           2  2020-07-17 00:01:26.825  19088202  0.000026  sell    25.0
# 3           3  2020-07-17 00:01:26.841  19088203  0.000026  sell   235.0
# 4           4  2020-07-17 00:01:26.842  19088204  0.000026  sell    36.0
# Contour metric does not work with forecast_length == 1
# Inferred frequency is: None
# Frequency is 'None'! Input frequency not recognized.
# One or more series is 90% or more NaN in this train split
# One or more series is 90% or more NaN in this test split
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 1: AverageValueNaive
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model DatepartRegression in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 7: DatepartRegression
# Model Number: 8 with model ETS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model GLM in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 22: LastValueNaive
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError('obj must have the same number of elements in axis 0 as orig') in model 28: UnobservedComponents
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError("Invalid value for 'n_quantiles': 0. The number of quantiles must be at least one.") in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 39 with model ZeroesNaive in generation 0 of 10
# Model Number: 40 with model ZeroesNaive in generation 0 of 10
# Model Number: 41 with model LastValueNaive in generation 0 of 10
# Model Number: 42 with model AverageValueNaive in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 42: AverageValueNaive
# Model Number: 43 with model GLS in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 43: GLS
# Model Number: 44 with model SeasonalNaive in generation 0 of 10
# Model Number: 45 with model GLM in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 46 with model ETS in generation 0 of 10
# Model Number: 47 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 47: FBProphet
# Model Number: 48 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 48: GluonTS
# Model Number: 49 with model UnobservedComponents in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 50 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 50: VAR
# Model Number: 51 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 51: VECM
# Model Number: 52 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 52: WindowRegression
# Model Number: 53 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 53: DatepartRegression
# Model Number: 54 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (3)') in model 54: UnivariateMotif
# Model Number: 55 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('The number of observations (7) is too small; the covariance matrix is singular. For observations with 7 dimensions, at least 8 observations are required.') in model 55: MultivariateMotif
# Model Number: 56 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (3)') in model 56: SectionalMotif
# Model Number: 57 with model NVAR in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 13 observation(s)') in model 57: NVAR
# Model Number: 58 with model Theta in generation 0 of 10
# Template Eval Error: ValueError("Invalid value for 'n_quantiles': 0. The number of quantiles must be at least one.") in model 58: Theta
# Model Number: 59 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 59: ARDL
# Model Number: 60 with model ETS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 61 with model ZeroesNaive in generation 0 of 10
# Template Eval Error: ValueError('max() arg is an empty sequence') in model 61: ZeroesNaive
# Model Number: 62 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 62: UnivariateMotif
# Model Number: 63 with model LastValueNaive in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 63: LastValueNaive
# Model Number: 64 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 64: ARDL
# Model Number: 65 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError('obj must have the same number of elements in axis 0 as orig') in model 65: UnobservedComponents
# Model Number: 66 with model SeasonalNaive in generation 0 of 10
# Model Number: 67 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 67: VAR
# Model Number: 68 with model LastValueNaive in generation 0 of 10
# Model Number: 69 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('The number of observations (4) is too small; the covariance matrix is singular. For observations with 10 dimensions, at least 11 observations are required.') in model 69: UnivariateMotif
# Model Number: 70 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 70: VAR
# Model Number: 71 with model ZeroesNaive in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 71: ZeroesNaive
# Model Number: 72 with model UnobservedComponents in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 73 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 73: ARDL
# Model Number: 74 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Shape of passed values is (13, 14), indices imply (13, 1)') in model 74: VAR
# Model Number: 75 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 75: SectionalMotif
# Model Number: 76 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 76: ARDL
# Model Number: 77 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 77: ARDL
# Model Number: 78 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 78: VAR
# Model Number: 79 with model AverageValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1368: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# Model Number: 80 with model VAR in generation 0 of 10
# Template Eval Error: IndexError('tuple index out of range') in model 80: VAR
# Model Number: 81 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 81: VAR
# Model Number: 82 with model SeasonalNaive in generation 0 of 10
# Model Number: 83 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 83: WindowRegression
# Model Number: 84 with model Theta in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 85 with model Theta in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 86 with model Theta in generation 0 of 10
# Model Number: 87 with model LastValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 88 with model AverageValueNaive in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 88: AverageValueNaive
# Model Number: 89 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('Unable to determine period from endog') in model 89: Theta
# Model Number: 90 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 90: VAR
# Model Number: 91 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 91: VAR
# Model Number: 92 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 92: FBProphet
# Model Number: 93 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 93: VECM
# Model Number: 94 with model SeasonalNaive in generation 0 of 10
# Model Number: 95 with model GluonTS in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 95: GluonTS
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 96 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 96: VAR
# Model Number: 97 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 97: SectionalMotif
# Model Number: 98 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 98: UnobservedComponents
# Model Number: 99 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 99: VAR
# Model Number: 100 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 100: UnobservedComponents
# Model Number: 101 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 101: DatepartRegression
# Model Number: 102 with model LastValueNaive in generation 0 of 10
# Model Number: 103 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 103: ARDL
# Model Number: 104 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 104: ARDL
# Model Number: 105 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 105: WindowRegression
# Model Number: 106 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 106: VECM
# Model Number: 107 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 107: GluonTS
# Model Number: 108 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 108: VECM
# Model Number: 109 with model ZeroesNaive in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 109: ZeroesNaive
# Model Number: 110 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 110: FBProphet
# Model Number: 111 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=3) out of bounds (3)') in model 111: MultivariateMotif
# Model Number: 112 with model GLS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 113 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 113: ARDL
# Model Number: 114 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=3) out of bounds (3)') in model 114: MultivariateMotif
# Model Number: 115 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 13 observation(s)') in model 115: Theta
# Model Number: 116 with model GLS in generation 0 of 10
# Model Number: 117 with model DatepartRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 118 with model NVAR in generation 0 of 10
# Model Number: 119 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 119: VAR
# Model Number: 120 with model ZeroesNaive in generation 0 of 10
# Model Number: 121 with model SeasonalNaive in generation 0 of 10
# Model Number: 122 with model ETS in generation 0 of 10
# Model Number: 123 with model LastValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 124 with model AverageValueNaive in generation 0 of 10
# Model Number: 125 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 125: VECM
# Model Number: 126 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 126: MultivariateMotif
# Model Number: 127 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 127: DatepartRegression
# Model Number: 128 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 128: VECM
# Model Number: 129 with model GLS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 130 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 130: WindowRegression
# Model Number: 131 with model SectionalMotif in generation 0 of 10
# Template Eval Error: IndexError('index -1 is out of bounds for axis 0 with size 0') in model 131: SectionalMotif
# Model Number: 132 with model AverageValueNaive in generation 0 of 10
# Model Number: 133 with model LastValueNaive in generation 0 of 10
# Model Number: 134 with model Theta in generation 0 of 10
# Model Number: 135 with model NVAR in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\_pca.py:468: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ = (S ** 2) / (n_samples - 1)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 136 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 136: MultivariateMotif
# Model Number: 137 with model DatepartRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 138 with model NVAR in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 139 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 139: Theta
# New Generation: 1 of 10
# Model Number: 140 with model AverageValueNaive in generation 1 of 10
# Model Number: 141 with model AverageValueNaive in generation 1 of 10
# Model Number: 142 with model AverageValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 142: AverageValueNaive
# Model Number: 143 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 143: DatepartRegression
# Model Number: 144 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 144: DatepartRegression
# Model Number: 145 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 145: DatepartRegression
# Model Number: 146 with model ETS in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 147 with model ETS in generation 1 of 10
# Model Number: 148 with model ETS in generation 1 of 10
# Model Number: 149 with model ETS in generation 1 of 10
# Model Number: 150 with model GLM in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 151 with model GLM in generation 1 of 10
# Model Number: 152 with model GLM in generation 1 of 10
# Model Number: 153 with model GLM in generation 1 of 10
# Model Number: 154 with model GLS in generation 1 of 10
# Model Number: 155 with model GLS in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 155: GLS
# Model Number: 156 with model GLS in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 157 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 157: GluonTS
# Model Number: 158 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 158: GluonTS
# Model Number: 159 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 159: GluonTS
# Model Number: 160 with model GluonTS in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 160: GluonTS
# Model Number: 161 with model LastValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 161: LastValueNaive
# Model Number: 162 with model LastValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 162: LastValueNaive
# Model Number: 163 with model SeasonalNaive in generation 1 of 10
# Model Number: 164 with model SeasonalNaive in generation 1 of 10
# Model Number: 165 with model SeasonalNaive in generation 1 of 10
# Template Eval Error: ValueError("Invalid value for 'n_quantiles': 0. The number of quantiles must be at least one.") in model 165: SeasonalNaive
# Model Number: 166 with model SeasonalNaive in generation 1 of 10
# Template Eval Error: ValueError("Invalid value for 'n_quantiles': 0. The number of quantiles must be at least one.") in model 166: SeasonalNaive
# Model Number: 167 with model UnobservedComponents in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
# ...
# Model Number: 71 of 102 with model ZeroesNaive for Validation 2
# 71 - ZeroesNaive with avg smape nan:
# Model Number: 72 of 102 with model NVAR for Validation 2
# 72 - NVAR with avg smape nan:
# Model Number: 73 of 102 with model NVAR for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 73 - NVAR with avg smape nan:
# Model Number: 74 of 102 with model Theta for Validation 2
# 74 - Theta with avg smape nan:
# Model Number: 75 of 102 with model Theta for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 75 - Theta with avg smape nan:
# Model Number: 76 of 102 with model AverageValueNaive for Validation 2
# 76 - AverageValueNaive with avg smape nan:
# Model Number: 77 of 102 with model DatepartRegression for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 77 - DatepartRegression with avg smape nan:
# Model Number: 78 of 102 with model DatepartRegression for Validation 2
# 78 - DatepartRegression with avg smape nan:
# Model Number: 79 of 102 with model GLM for Validation 2
# 79 - GLM with avg smape nan:
# Model Number: 80 of 102 with model GLS for Validation 2
# 80 - GLS with avg smape nan:
# Model Number: 81 of 102 with model UnobservedComponents for Validation 2
# 81 - UnobservedComponents with avg smape nan:
# Model Number: 82 of 102 with model ZeroesNaive for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\_tools.py:121: RuntimeWarning: invalid value encountered in double_scalars
#   scale = np.dot(wresid, wresid) / df_resid
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\_tools.py:121: RuntimeWarning: divide by zero encountered in double_scalars
#   scale = np.dot(wresid, wresid) / df_resid
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 82 - ZeroesNaive with avg smape nan:
# Model Number: 83 of 102 with model NVAR for Validation 2
# 83 - NVAR with avg smape nan:
# Model Number: 84 of 102 with model Theta for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 84 - Theta with avg smape nan:
# Model Number: 85 of 102 with model Theta for Validation 2
# 85 - Theta with avg smape nan:
# Model Number: 86 of 102 with model ZeroesNaive for Validation 2
# 86 - ZeroesNaive with avg smape nan:
# Model Number: 87 of 102 with model ZeroesNaive for Validation 2
# 87 - ZeroesNaive with avg smape nan:
# Model Number: 88 of 102 with model ZeroesNaive for Validation 2
# 88 - ZeroesNaive with avg smape nan:
# Model Number: 89 of 102 with model NVAR for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 89 - NVAR with avg smape nan:
# Model Number: 90 of 102 with model NVAR for Validation 2
# 90 - NVAR with avg smape nan:
# Model Number: 91 of 102 with model DatepartRegression for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 91 - DatepartRegression with avg smape nan:
# Model Number: 92 of 102 with model WindowRegression for Validation 2
# 92 - WindowRegression with avg smape nan:
# Model Number: 93 of 102 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3') in model 93: WindowRegression
# Model Number: 94 of 102 with model MultivariateMotif for Validation 2
# 94 - MultivariateMotif with avg smape nan:
# Model Number: 95 of 102 with model MultivariateMotif for Validation 2
# 95 - MultivariateMotif with avg smape nan:
# Model Number: 96 of 102 with model SectionalMotif for Validation 2
# Template Eval Error: ValueError('kth(=1) out of bounds (1)') in model 96: SectionalMotif
# Model Number: 97 of 102 with model MultivariateMotif for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 97 - MultivariateMotif with avg smape nan:
# Model Number: 98 of 102 with model WindowRegression for Validation 2
# 98 - WindowRegression with avg smape nan:
# Model Number: 99 of 102 with model MultivariateMotif for Validation 2
# 99 - MultivariateMotif with avg smape nan:
# Model Number: 100 of 102 with model WindowRegression for Validation 2
# 100 - WindowRegression with avg smape nan:
# Model Number: 101 of 102 with model WindowRegression for Validation 2
# 101 - WindowRegression with avg smape nan:
# Model Number: 102 of 102 with model Ensemble for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\link.py:84: RuntimeWarning: divide by zero encountered in log
#   return np.log(y_pred)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\_loss\glm_distribution.py:315: RuntimeWarning: invalid value encountered in true_divide
#   dev = 2 * (xlogy(y, y/y_pred) - y + y_pred)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_glm\glm.py:287: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 102 - Ensemble with avg smape nan:
# IOTA/BTC .predict is
#                             price
# 2020-07-31 00:01:10.647  0.000026
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
import datetime
#d = datetime.datetime.strptime('2011-06-09', '%Y-%m-%d')
#d.strftime('%b %d,%Y')


sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv(r"C:\Users/Hp/Desktop/challenge/trades.csv")
#print("Shape of Dataset is: ",data.shape,"\n")
#print(data)
data1['timestamp'] = pd.to_datetime(data1['timestamp'])

data = data1[~(data1['timestamp'] > '2020-07-28 17:53:05')]

print(res)
# Out:
#        Unnamed: 0               timestamp        id     price  side  amount
# 0               0 2020-07-17 00:01:10.647  19088200  0.000026   buy     4.0
# 1               1 2020-07-17 00:01:26.820  19088201  0.000026  sell    58.0
# 2               2 2020-07-17 00:01:26.825  19088202  0.000026  sell    25.0
# 3               3 2020-07-17 00:01:26.841  19088203  0.000026  sell   235.0
# 4               4 2020-07-17 00:01:26.842  19088204  0.000026  sell    36.0
# ...           ...                     ...       ...       ...   ...     ...
# 75140       75140 2020-07-28 17:49:40.486  19163346  0.000025  sell   506.0
# 75141       75141 2020-07-28 17:50:31.902  19163347  0.000025   buy     1.0
# 75142       75142 2020-07-28 17:50:35.492  19163348  0.000025   buy   505.0
# 75143       75143 2020-07-28 17:51:52.752  19163349  0.000025   buy    90.0
# 75144       75144 2020-07-28 17:51:59.923  19163350  0.000025   buy    10.0
#
# [75145 rows x 6 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
import datetime
#d = datetime.datetime.strptime('2011-06-09', '%Y-%m-%d')
#d.strftime('%b %d,%Y')


sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv(r"C:\Users/Hp/Desktop/challenge/trades.csv")

#data['timestamp'] = pd.to_datetime(data['timestamp'])
#value = input("Please enter date with this form --->yyyy-mm-dd hh:mm:ss")
 
#print(f'You entered {value}')
#data = data1[~(data1['timestamp'] > value)]
data = data[~(data['timestamp'] > '2020-07-29 17:53:05')]


print("thetyperofdata is: ",data.shape,"\n")
print(data.head())

data.dropna()
plt.figure(figsize=(10, 4))
plt.title("IOTA/BTC")
plt.xlabel("timestamp")
plt.ylabel("price")
plt.plot(data["price"])
plt.show()


from autots import AutoTS
model = AutoTS(forecast_length=1, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col='timestamp', value_col='price', id_col=None)
 
prediction = model.predict()
forecast = prediction.forecast
print("IOTA/BTC .predict is ")
print(forecast)
print(forecast)
print(forecast)
print(forecast)

forecastnumber = forecast[forecast.columns[-1]]
length = len(forecastnumber)
forecastnumber = forecastnumber[length -1]
forecastnumber= float(forecastnumber)

#forecastnumber = forecast[forecast.columns[ -1:, -1:]]
#forecastnumber = int(forecastnumber)
print(forecastnumber)
# Out:
# thetyperofdata is:  (75145, 6)
#
#    Unnamed: 0                timestamp        id     price  side  amount
# 0           0  2020-07-17 00:01:10.647  19088200  0.000026   buy     4.0
# 1           1  2020-07-17 00:01:26.820  19088201  0.000026  sell    58.0
# 2           2  2020-07-17 00:01:26.825  19088202  0.000026  sell    25.0
# 3           3  2020-07-17 00:01:26.841  19088203  0.000026  sell   235.0
# 4           4  2020-07-17 00:01:26.842  19088204  0.000026  sell    36.0
# Contour metric does not work with forecast_length == 1
# Inferred frequency is: None
# Frequency is 'None'! Input frequency not recognized.
# One or more series is 90% or more NaN in this train split
# One or more series is 90% or more NaN in this test split
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 1: AverageValueNaive
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model DatepartRegression in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 7: DatepartRegression
# Model Number: 8 with model ETS in generation 0 of 10
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model GLM in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 22: LastValueNaive
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError('obj must have the same number of elements in axis 0 as orig') in model 28: UnobservedComponents
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError("Invalid value for 'n_quantiles': 0. The number of quantiles must be at least one.") in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 10
# Model Number: 39 with model ZeroesNaive in generation 0 of 10
# Model Number: 40 with model ZeroesNaive in generation 0 of 10
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 12: given 1') in model 40: ZeroesNaive
# Model Number: 41 with model LastValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1389: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# Model Number: 42 with model AverageValueNaive in generation 0 of 10
# Model Number: 43 with model GLS in generation 0 of 10
# Model Number: 44 with model SeasonalNaive in generation 0 of 10
# Model Number: 45 with model GLM in generation 0 of 10
# Model Number: 46 with model ETS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 47 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 47: FBProphet
# Model Number: 48 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 48: GluonTS
# Model Number: 49 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 49: UnobservedComponents
# Model Number: 50 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 50: VAR
# Model Number: 51 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 51: VECM
# Model Number: 52 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 52: WindowRegression
# Model Number: 53 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 53: DatepartRegression
# Model Number: 54 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 54: UnivariateMotif
# Model Number: 55 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (1)') in model 55: MultivariateMotif
# Model Number: 56 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (1)') in model 56: SectionalMotif
# Model Number: 57 with model NVAR in generation 0 of 10
# Model Number: 58 with model Theta in generation 0 of 10
# Model Number: 59 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 59: ARDL
# Model Number: 60 with model GLM in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 61 with model NVAR in generation 0 of 10
# Model Number: 62 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 11 observation(s)') in model 62: GLM
# Model Number: 63 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 63: WindowRegression
# Model Number: 64 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 64: GLM
# Model Number: 65 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 65: ARDL
# Model Number: 66 with model Theta in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 67 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 67: UnobservedComponents
# Model Number: 68 with model Theta in generation 0 of 10
# Model Number: 69 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 69: GLM
# Model Number: 70 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 11 observation(s)') in model 70: Theta
# Model Number: 71 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 71: ARDL
# Model Number: 72 with model UnobservedComponents in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 73 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 73: VECM
# Model Number: 74 with model NVAR in generation 0 of 10
# Model Number: 75 with model ETS in generation 0 of 10
# Model Number: 76 with model FBProphet in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 76: FBProphet
# Model Number: 77 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 77: VECM
# Model Number: 78 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 78: MultivariateMotif
# Model Number: 79 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 79: GLM
# Model Number: 80 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 80: FBProphet
# Model Number: 81 with model AverageValueNaive in generation 0 of 10
# Model Number: 82 with model FBProphet in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:179: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 82: FBProphet
# Model Number: 83 with model ETS in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 83: ETS
# Model Number: 84 with model GLS in generation 0 of 10
# Model Number: 85 with model GLM in generation 0 of 10
# Model Number: 86 with model WindowRegression in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'xgboost'") in model 86: WindowRegression
# Model Number: 87 with model AverageValueNaive in generation 0 of 10
# Model Number: 88 with model SeasonalNaive in generation 0 of 10
# Model Number: 89 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('obj must have the same number of elements in axis 0 as orig') in model 89: VAR
# Model Number: 90 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 90: ARDL
# Model Number: 91 with model LastValueNaive in generation 0 of 10
# Model Number: 92 with model AverageValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\genmod\families\family.py:428: RuntimeWarning: divide by zero encountered in true_divide
#   endog_mu = self._clean(endog / mu)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 93 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 93: ARDL
# Model Number: 94 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 94: VAR
# Model Number: 95 with model DatepartRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# Model Number: 96 with model ETS in generation 0 of 10
# Model Number: 97 with model NVAR in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 98 with model Theta in generation 0 of 10
# Model Number: 99 with model ETS in generation 0 of 10
# Model Number: 100 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('`min_samples` may not be larger than number of samples: n_samples = 1.') in model 100: WindowRegression
# Model Number: 101 with model GluonTS in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 101: GluonTS
# Model Number: 102 with model FBProphet in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 102: FBProphet
# Model Number: 103 with model GLS in generation 0 of 10
# Model Number: 104 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 104: GLM
# Model Number: 105 with model NVAR in generation 0 of 10
# Model Number: 106 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 106: DatepartRegression
# Model Number: 107 with model GluonTS in generation 0 of 10
# Template Eval Error: ValueError('obj must have the same number of elements in axis 0 as orig') in model 107: GluonTS
# Model Number: 108 with model SeasonalNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 109 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 109: ARDL
# Model Number: 110 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 110: GluonTS
# Model Number: 111 with model ZeroesNaive in generation 0 of 10
# Model Number: 112 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 112: GluonTS
# Model Number: 113 with model ETS in generation 0 of 10
# Template Eval Error: ValueError('zero-size array to reduction operation maximum which has no identity') in model 113: ETS
# Model Number: 114 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 114: VECM
# Model Number: 115 with model SeasonalNaive in generation 0 of 10
# Model Number: 116 with model SeasonalNaive in generation 0 of 10
# Model Number: 117 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('RANSAC could not find a valid consensus set. All `max_trials` iterations were skipped because each randomly chosen sub-sample failed the passing criteria. See estimator attributes for diagnostics (n_skips*).') in model 117: WindowRegression
# Model Number: 118 with model AverageValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 119 with model LastValueNaive in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 119: LastValueNaive
# Model Number: 120 with model NVAR in generation 0 of 10
# Model Number: 121 with model GLM in generation 0 of 10
# Model Number: 122 with model AverageValueNaive in generation 0 of 10
# Model Number: 123 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 123: VAR
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 124 with model Theta in generation 0 of 10
# Model Number: 125 with model ETS in generation 0 of 10
# Template Eval Error: KeyError(Timestamp('2020-07-17 00:01:10.647000', freq='D')) in model 125: ETS
# Model Number: 126 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=3) out of bounds (1)') in model 126: MultivariateMotif
# Model Number: 127 with model NVAR in generation 0 of 10
# Model Number: 128 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (1)') in model 128: SectionalMotif
# Model Number: 129 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('The number of observations (2) is too small; the covariance matrix is singular. For observations with 10 dimensions, at least 11 observations are required.') in model 129: SectionalMotif
# Model Number: 130 with model ETS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 131 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=3) out of bounds (1)') in model 131: MultivariateMotif
# Model Number: 132 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 132: VAR
# Model Number: 133 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 133: Theta
# Model Number: 134 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=3) out of bounds (1)') in model 134: SectionalMotif
# Model Number: 135 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 135: WindowRegression
# Model Number: 136 with model ZeroesNaive in generation 0 of 10
# Model Number: 137 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 137: ARDL
# Model Number: 138 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 138: WindowRegression
# Model Number: 139 with model ETS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# New Generation: 1 of 10
# Model Number: 140 with model AverageValueNaive in generation 1 of 10
# Model Number: 141 with model AverageValueNaive in generation 1 of 10
# Model Number: 142 with model AverageValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 142: AverageValueNaive
# Model Number: 143 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 143: DatepartRegression
# Model Number: 144 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 144: DatepartRegression
# Model Number: 145 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 145: DatepartRegression
# Model Number: 146 with model ETS in generation 1 of 10
# Model Number: 147 with model ETS in generation 1 of 10
# Model Number: 148 with model ETS in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 149 with model ETS in generation 1 of 10
# Model Number: 150 with model GLM in generation 1 of 10
# Model Number: 151 with model GLM in generation 1 of 10
# Model Number: 152 with model GLM in generation 1 of 10
# Model Number: 153 with model GLM in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 154 with model GLS in generation 1 of 10
# Model Number: 155 with model GLS in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 155: GLS
# Model Number: 156 with model GLS in generation 1 of 10
# Model Number: 157 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 157: GluonTS
# Model Number: 158 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 158: GluonTS
# Model Number: 159 with model GluonTS in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 159: GluonTS
# Model Number: 160 with model LastValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 160: LastValueNaive
# Model Number: 161 with model LastValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 161: LastValueNaive
# Model Number: 162 with model SeasonalNaive in generation 1 of 10
# Model Number: 163 with model SeasonalNaive in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# ...
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 64 - GLM with avg smape nan:
# Model Number: 65 of 96 with model GLM for Validation 2
# 65 - GLM with avg smape nan:
# Model Number: 66 of 96 with model GLS for Validation 2
# 66 - GLS with avg smape nan:
# Model Number: 67 of 96 with model GLS for Validation 2
# 67 - GLS with avg smape nan:
# Model Number: 68 of 96 with model UnobservedComponents for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 68 - UnobservedComponents with avg smape nan:
# Model Number: 69 of 96 with model UnobservedComponents for Validation 2
# 69 - UnobservedComponents with avg smape nan:
# Model Number: 70 of 96 with model UnobservedComponents for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 70 - UnobservedComponents with avg smape nan:
# Model Number: 71 of 96 with model WindowRegression for Validation 2
# 71 - WindowRegression with avg smape nan:
# Model Number: 72 of 96 with model ZeroesNaive for Validation 2
# 72 - ZeroesNaive with avg smape nan:
# Model Number: 73 of 96 with model ZeroesNaive for Validation 2
# 73 - ZeroesNaive with avg smape nan:
# Model Number: 74 of 96 with model NVAR for Validation 2
# 74 - NVAR with avg smape nan:
# Model Number: 75 of 96 with model Theta for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 75 - Theta with avg smape nan:
# Model Number: 76 of 96 with model Theta for Validation 2
# 76 - Theta with avg smape nan:
# Model Number: 77 of 96 with model GLS for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 77 - GLS with avg smape nan:
# Model Number: 78 of 96 with model UnobservedComponents for Validation 2
# 78 - UnobservedComponents with avg smape nan:
# Model Number: 79 of 96 with model ZeroesNaive for Validation 2
# 79 - ZeroesNaive with avg smape nan:
# Model Number: 80 of 96 with model ZeroesNaive for Validation 2
# 80 - ZeroesNaive with avg smape nan:
# Model Number: 81 of 96 with model ZeroesNaive for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 81 - ZeroesNaive with avg smape nan:
# Model Number: 82 of 96 with model UnivariateMotif for Validation 2
# Template Eval Error: ValueError('kth(=3) out of bounds (2)') in model 82: UnivariateMotif
# Model Number: 83 of 96 with model SectionalMotif for Validation 2
# 83 - SectionalMotif with avg smape nan:
# Model Number: 84 of 96 with model Theta for Validation 2
# 84 - Theta with avg smape nan:
# Model Number: 85 of 96 with model DatepartRegression for Validation 2
# 85 - DatepartRegression with avg smape nan:
# Model Number: 86 of 96 with model LastValueNaive for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\_pca.py:470: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ratio_ = explained_variance_ / total_var
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 86 - LastValueNaive with avg smape nan:
# Model Number: 87 of 96 with model LastValueNaive for Validation 2
# 87 - LastValueNaive with avg smape nan:
# Model Number: 88 of 96 with model LastValueNaive for Validation 2
# 88 - LastValueNaive with avg smape nan:
# Model Number: 89 of 96 with model UnobservedComponents for Validation 2
# 89 - UnobservedComponents with avg smape nan:
# Model Number: 90 of 96 with model DatepartRegression for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 90 - DatepartRegression with avg smape nan:
# Model Number: 91 of 96 with model DatepartRegression for Validation 2
# 91 - DatepartRegression with avg smape nan:
# Model Number: 92 of 96 with model DatepartRegression for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 92 - DatepartRegression with avg smape nan:
# Model Number: 93 of 96 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 93: WindowRegression
# Model Number: 94 of 96 with model MultivariateMotif for Validation 2
# Template Eval Error: ValueError('kth(=3) out of bounds (2)') in model 94: MultivariateMotif
# Model Number: 95 of 96 with model WindowRegression for Validation 2
# 95 - WindowRegression with avg smape nan:
# Model Number: 96 of 96 with model Ensemble for Validation 2
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.0s finished
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 96 - Ensemble with avg smape nan:
# IOTA/BTC .predict is
#                             price
# 2020-07-29 00:01:10.647  0.000026
#                             price
# 2020-07-29 00:01:10.647  0.000026
#                             price
# 2020-07-29 00:01:10.647  0.000026
#                             price
# 2020-07-29 00:01:10.647  0.000026
# 2.643e-05
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)

# %%
print(forecastnumber)



data = pd.read_csv(r"C:\Users/Hp/Desktop/challenge/trades.csv")
  
df = pd.DataFrame(data,columns=['timestamp','price',])

df.plot(x ='timestamp', y='price', kind = 'line')



data['timestamp'] = pd.to_datetime(data['timestamp'])
#value = input("Please enter date with this form --->yyyy-mm-dd hh:mm:ss")
 
#print(f'You entered {value}')
#data = data1[~(data1['timestamp'] > value)]
data = data[~(data['timestamp'] > '2020-07-29 17:53:05')]

ask1= int(forecastnumber())
bid1= int(forecastnumber())

asksum = ask1 * 1.02
askdif = asksum - ask1
bidsum = bid1 - askdif

asksum1 = int(asksum)
bidsum1 = int(bidsum)
#print(askdif)
plt.axhline(y = asksum1, xmin=0.93, xmax=1.5, color = 'r', linestyle = '-')
plt.axhline(y = bidsum1, xmin=0.93, color = 'g', linestyle = '-')


plt.show()
# Out:
# 2.643e-05
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28404/1553910865.py in <module>
#      18 data = data[~(data['timestamp'] > '2020-07-29 17:53:05')]
#      19
# ---> 20 ask1= int(forecastnumber())
#      21 bid1= int(forecastnumber())
#      22
#
# TypeError: 'numpy.float64' object is not callable

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
import datetime
#d = datetime.datetime.strptime('2011-06-09', '%Y-%m-%d')
#d.strftime('%b %d,%Y')


sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv(r"C:\Users/Hp/Desktop/challenge/trades.csv")

data['timestamp'] = pd.to_datetime(data['timestamp'])
#value = input("Please enter date with this form --->yyyy-mm-dd hh:mm:ss")
 
#print(f'You entered {value}')
#data = data1[~(data1['timestamp'] > value)]
data = data[~(data['timestamp'] > '2020-07-29 17:53:05')]


print("thetyperofdata is: ",data.shape,"\n")
print(data.head())

data.dropna()
plt.figure(figsize=(10, 4))
plt.title("IOTA/BTC")
plt.xlabel("timestamp")
plt.ylabel("price")
plt.plot(data["price"])
plt.show()


from autots import AutoTS
model = AutoTS(forecast_length=1, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col='timestamp', value_col='price', id_col=None)
 
prediction = model.predict()
forecast = prediction.forecast
print("IOTA/BTC .predict is ")
print(forecast)
print(forecast)
print(forecast)
print(forecast)

forecastnumber = forecast[forecast.columns[-1]]
length = len(forecastnumber)
forecastnumber = forecastnumber[length -1]

#forecastnumber = forecast[forecast.columns[ -1:, -1:]]
#forecastnumber = int(forecastnumber)
float(forecastnumber)

print(str(forecastnumber))
print(float(forecastnumber))
print("%.9f" % (forecastnumber))

numberwearelookingfor = ("%.9f" % (forecastnumber))

ask1= numberwearelookingfor
#bid1= int(forecastnumber())
print(numberwearelookingfor)



data = pd.read_csv(r"C:\Users/Hp/Desktop/challenge/trades.csv")
  
df = pd.DataFrame(data,columns=['timestamp','price',])

df.plot(x ='timestamp', y='price', kind = 'line')



data['timestamp'] = pd.to_datetime(data['timestamp'])
#value = input("Please enter date with this form --->yyyy-mm-dd hh:mm:ss")
 
#print(f'You entered {value}')
#data = data1[~(data1['timestamp'] > value)]
data = data[~(data['timestamp'] > '2020-07-29 17:53:05')]





ask1= float(numberwearelookingfor)
bid1= float(numberwearelookingfor)
ask3= float(numberwearelookingfor)

asksum = ask1 * 1.05
askdif = asksum - ask1
bidsum = bid1 - askdif

asksum1 = float(asksum)
bidsum1 = float(bidsum)
#print(askdif)

#asksum2 = ask1 * 1.047
#askdif2 = asksum2 - ask1
#bidsum2 = bid1 - askdif2

#asksum2 = float(asksum2)
#bidsum2 = float(bidsum2)



#asksum3 = ask1 * 1.045
#askdif3 = asksum3 - ask1
#bidsum3 = bid1 - askdif3

#asksum3 = float(asksum2)
#bidsum3 = float(bidsum2)


#plt.axhline(y = asksum3, xmin=0.93, xmax=1.5, color = 'y', linestyle = '-')
plt.axhline(y = asksum1, xmin=0.93, xmax=1.5, color = 'r', linestyle = '-')
plt.axhline(y = bidsum1, xmin=0.93, color = 'g', linestyle = '-')
#level2
#plt.axhline(y = asksum2, xmin=0.93, xmax=1.5, color = 'r', linestyle = '-')
#plt.axhline(y = bidsum2, xmin=0.93, color = 'g', linestyle = '-')
#level3
#plt.axhline(y = asksum3, xmin=0.93, xmax=1.5, color = 'r', linestyle = '-')
#plt.axhline(y = bidsum3, xmin=0.93, color = 'g', linestyle = '-')


plt.show()
# Out:
# thetyperofdata is:  (81634, 6)
#
#    Unnamed: 0               timestamp        id     price  side  amount
# 0           0 2020-07-17 00:01:10.647  19088200  0.000026   buy     4.0
# 1           1 2020-07-17 00:01:26.820  19088201  0.000026  sell    58.0
# 2           2 2020-07-17 00:01:26.825  19088202  0.000026  sell    25.0
# 3           3 2020-07-17 00:01:26.841  19088203  0.000026  sell   235.0
# 4           4 2020-07-17 00:01:26.842  19088204  0.000026  sell    36.0
# Contour metric does not work with forecast_length == 1
# Inferred frequency is: None
# Frequency is 'None'! Input frequency not recognized.
# One or more series is 90% or more NaN in this train split
# One or more series is 90% or more NaN in this test split
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 1: AverageValueNaive
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model DatepartRegression in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 7: DatepartRegression
# Model Number: 8 with model ETS in generation 0 of 10
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model GLM in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLS in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 14 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 22: LastValueNaive
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError('obj must have the same number of elements in axis 0 as orig') in model 28: UnobservedComponents
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError("Invalid value for 'n_quantiles': 0. The number of quantiles must be at least one.") in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 39 with model ZeroesNaive in generation 0 of 10
# Model Number: 40 with model ZeroesNaive in generation 0 of 10
# Model Number: 41 with model LastValueNaive in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 41: LastValueNaive
# Model Number: 42 with model AverageValueNaive in generation 0 of 10
# Template Eval Error: IndexError('tuple index out of range') in model 42: AverageValueNaive
# Model Number: 43 with model GLS in generation 0 of 10
# Model Number: 44 with model SeasonalNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\filters\cf_filter.py:81: RuntimeWarning: invalid value encountered in true_divide
#   x = x - np.arange(nobs)[:, None] * (x[-1] - x[0]) / (nobs - 1)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 45 with model GLM in generation 0 of 10
# Template Eval Error: PerfectSeparationError('Perfect separation detected, results not available') in model 45: GLM
# Model Number: 46 with model ETS in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 12 observation(s)') in model 46: ETS
# Model Number: 47 with model FBProphet in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 47: FBProphet
# Model Number: 48 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 48: GluonTS
# Model Number: 49 with model UnobservedComponents in generation 0 of 10
# Model Number: 50 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 50: VAR
# Model Number: 51 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 51: VECM
# Model Number: 52 with model WindowRegression in generation 0 of 10
# Model Number: 53 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 53: DatepartRegression
# Model Number: 54 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 54: UnivariateMotif
# Model Number: 55 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 55: MultivariateMotif
# Model Number: 56 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 56: SectionalMotif
# Model Number: 57 with model NVAR in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 57: NVAR
# Model Number: 58 with model Theta in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 59 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 59: ARDL
# Model Number: 60 with model ZeroesNaive in generation 0 of 10
# Model Number: 61 with model LastValueNaive in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 12 observation(s)') in model 61: LastValueNaive
# Model Number: 62 with model Theta in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 63 with model GluonTS in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 12 observation(s)') in model 63: GluonTS
# Model Number: 64 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 64: ARDL
# Model Number: 65 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("Invalid value for 'n_quantiles': 0. The number of quantiles must be at least one.") in model 65: DatepartRegression
# Model Number: 66 with model LastValueNaive in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 66: LastValueNaive
# Model Number: 67 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 67: GluonTS
# Model Number: 68 with model SeasonalNaive in generation 0 of 10
# Model Number: 69 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 69: ARDL
# Model Number: 70 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 70: GLM
# Model Number: 71 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 71: DatepartRegression
# Model Number: 72 with model LastValueNaive in generation 0 of 10
# Model Number: 73 with model GLS in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 74 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 74: VECM
# Model Number: 75 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (2)') in model 75: UnivariateMotif
# Model Number: 76 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 3, got 0+0') in model 76: DatepartRegression
# Model Number: 77 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=15) out of bounds (2)') in model 77: MultivariateMotif
# Model Number: 78 with model ZeroesNaive in generation 0 of 10
# Model Number: 79 with model GluonTS in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 79: GluonTS
# Model Number: 80 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 80: VAR
# Model Number: 81 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('XA and XB must have the same number of columns (i.e. feature dimension.)') in model 81: SectionalMotif
# Model Number: 82 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 82: UnobservedComponents
# Model Number: 83 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 83: VAR
# Model Number: 84 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 84: UnobservedComponents
# Model Number: 85 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 85: DatepartRegression
# Model Number: 86 with model LastValueNaive in generation 0 of 10
# Model Number: 87 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 87: ARDL
# Model Number: 88 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 88: ARDL
# Model Number: 89 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 89: WindowRegression
# Model Number: 90 with model VECM in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 90: VECM
# Model Number: 91 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 91: GluonTS
# Model Number: 92 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 92: VECM
# Model Number: 93 with model ZeroesNaive in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 93: ZeroesNaive
# Model Number: 94 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 94: FBProphet
# Model Number: 95 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=3) out of bounds (2)') in model 95: MultivariateMotif
# Model Number: 96 with model GLS in generation 0 of 10
# Model Number: 97 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 97: ARDL
# Model Number: 98 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=3) out of bounds (2)') in model 98: MultivariateMotif
# Model Number: 99 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('x must have 2 complete cycles requires 14 observations. x only has 12 observation(s)') in model 99: Theta
# Model Number: 100 with model GLS in generation 0 of 10
# Model Number: 101 with model DatepartRegression in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 102 with model NVAR in generation 0 of 10
# Model Number: 103 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 103: VAR
# Model Number: 104 with model ZeroesNaive in generation 0 of 10
# Model Number: 105 with model SeasonalNaive in generation 0 of 10
# Model Number: 106 with model ETS in generation 0 of 10
# Model Number: 107 with model LastValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 108 with model AverageValueNaive in generation 0 of 10
# Model Number: 109 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 109: VECM
# Model Number: 110 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('window shape cannot be larger than input array shape') in model 110: MultivariateMotif
# Model Number: 111 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 111: DatepartRegression
# Model Number: 112 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 112: VECM
# Model Number: 113 with model GLS in generation 0 of 10
# Model Number: 114 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 114: WindowRegression
# Model Number: 115 with model SectionalMotif in generation 0 of 10
# Template Eval Error: IndexError('index -1 is out of bounds for axis 0 with size 0') in model 115: SectionalMotif
# Model Number: 116 with model AverageValueNaive in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\_pca.py:468: RuntimeWarning: invalid value encountered in true_divide
#   explained_variance_ = (S ** 2) / (n_samples - 1)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 117 with model LastValueNaive in generation 0 of 10
# Model Number: 118 with model Theta in generation 0 of 10
# Model Number: 119 with model NVAR in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# Model Number: 120 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('`x` must contain at least 2 elements.') in model 120: MultivariateMotif
# Model Number: 121 with model DatepartRegression in generation 0 of 10
# Model Number: 122 with model NVAR in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 123 with model Theta in generation 0 of 10
# Template Eval Error: ValueError('The number of derivatives at boundaries does not match: expected 2, got 0+0') in model 123: Theta
# Model Number: 124 with model NVAR in generation 0 of 10
# Model Number: 125 with model WindowRegression in generation 0 of 10
# Template Eval Error: ImportError('Tensorflow not available, install with pip install tensorflow.') in model 125: WindowRegression
# Model Number: 126 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 126: VECM
# Model Number: 127 with model ETS in generation 0 of 10
# Model Number: 128 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (2)') in model 128: MultivariateMotif
# Model Number: 129 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 129: SectionalMotif
# Model Number: 130 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 130: WindowRegression
# Model Number: 131 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 131: VECM
# Model Number: 132 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError('x and y arrays must have at least 2 entries') in model 132: ARDL
# Model Number: 133 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (C:\\ProgramData\\Anaconda3\\lib\\site-packages\\statsmodels\\tsa\\api.py)") in model 133: ARDL
# Model Number: 134 with model VECM in generation 0 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 134: VECM
# Model Number: 135 with model NVAR in generation 0 of 10
# Model Number: 136 with model AverageValueNaive in generation 0 of 10
# Model Number: 137 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'prophet'") in model 137: FBProphet
# Model Number: 138 with model AverageValueNaive in generation 0 of 10
# Model Number: 139 with model ZeroesNaive in generation 0 of 10
# New Generation: 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 140 with model AverageValueNaive in generation 1 of 10
# Model Number: 141 with model AverageValueNaive in generation 1 of 10
# Model Number: 142 with model AverageValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 142: AverageValueNaive
# Model Number: 143 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 143: DatepartRegression
# Model Number: 144 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 144: DatepartRegression
# Model Number: 145 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 145: DatepartRegression
# Model Number: 146 with model ETS in generation 1 of 10
# Model Number: 147 with model ETS in generation 1 of 10
# Model Number: 148 with model ETS in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 149 with model ETS in generation 1 of 10
# Model Number: 150 with model GLM in generation 1 of 10
# Model Number: 151 with model GLM in generation 1 of 10
# Model Number: 152 with model GLM in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 153 with model GLM in generation 1 of 10
# Model Number: 154 with model GLS in generation 1 of 10
# Model Number: 155 with model GLS in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 155: GLS
# Model Number: 156 with model GLS in generation 1 of 10
# Model Number: 157 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 157: GluonTS
# Model Number: 158 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 158: GluonTS
# Model Number: 159 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 159: GluonTS
# Model Number: 160 with model GluonTS in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 160: GluonTS
# Model Number: 161 with model LastValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 161: LastValueNaive
# Model Number: 162 with model LastValueNaive in generation 1 of 10
# SinTrend failed with IndexError('index 1 is out of bounds for axis 0 with size 1') for price with 0
# Template Eval Error: ValueError('SinTrend Transformer failed on all series.') in model 162: LastValueNaive
# Model Number: 163 with model SeasonalNaive in generation 1 of 10
# Model Number: 164 with model SeasonalNaive in generation 1 of 10
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
# ...
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 59 - AverageValueNaive with avg smape nan:
# Model Number: 60 of 93 with model ETS for Validation 2
# 60 - ETS with avg smape nan:
# Model Number: 61 of 93 with model ETS for Validation 2
# 61 - ETS with avg smape nan:
# Model Number: 62 of 93 with model ETS for Validation 2
# 62 - ETS with avg smape nan:
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 63 of 93 with model ETS for Validation 2
# 63 - ETS with avg smape nan:
# Model Number: 64 of 93 with model GLM for Validation 2
# 64 - GLM with avg smape nan:
# Model Number: 65 of 93 with model GLM for Validation 2
# 65 - GLM with avg smape nan:
# Model Number: 66 of 93 with model GLM for Validation 2
# 66 - GLM with avg smape nan:
# Model Number: 67 of 93 with model GLM for Validation 2
# 67 - GLM with avg smape nan:
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# Model Number: 68 of 93 with model GLS for Validation 2
# 68 - GLS with avg smape nan:
# Model Number: 69 of 93 with model SeasonalNaive for Validation 2
# 69 - SeasonalNaive with avg smape nan:
# Model Number: 70 of 93 with model UnobservedComponents for Validation 2
# 70 - UnobservedComponents with avg smape nan:
# Model Number: 71 of 93 with model UnobservedComponents for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 71 - UnobservedComponents with avg smape nan:
# Model Number: 72 of 93 with model UnobservedComponents for Validation 2
# 72 - UnobservedComponents with avg smape nan:
# Model Number: 73 of 93 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 73: WindowRegression
# Model Number: 74 of 93 with model ZeroesNaive for Validation 2
# 74 - ZeroesNaive with avg smape nan:
# Model Number: 75 of 93 with model ZeroesNaive for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 75 - ZeroesNaive with avg smape nan:
# Model Number: 76 of 93 with model NVAR for Validation 2
# 76 - NVAR with avg smape nan:
# Model Number: 77 of 93 with model Theta for Validation 2
# 77 - Theta with avg smape nan:
# Model Number: 78 of 93 with model Theta for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 78 - Theta with avg smape nan:
# Model Number: 79 of 93 with model Theta for Validation 2
# 79 - Theta with avg smape nan:
# Model Number: 80 of 93 with model GLM for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 80 - GLM with avg smape nan:
# Model Number: 81 of 93 with model GLM for Validation 2
# 81 - GLM with avg smape nan:
# Model Number: 82 of 93 with model UnobservedComponents for Validation 2
# 82 - UnobservedComponents with avg smape nan:
# Model Number: 83 of 93 with model NVAR for Validation 2
# 83 - NVAR with avg smape nan:
# Model Number: 84 of 93 with model Theta for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 84 - Theta with avg smape nan:
# Model Number: 85 of 93 with model Theta for Validation 2
# 85 - Theta with avg smape nan:
# Model Number: 86 of 93 with model DatepartRegression for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 86 - DatepartRegression with avg smape nan:
# Model Number: 87 of 93 with model LastValueNaive for Validation 2
# 87 - LastValueNaive with avg smape nan:
# Model Number: 88 of 93 with model UnobservedComponents for Validation 2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 88 - UnobservedComponents with avg smape nan:
# Model Number: 89 of 93 with model WindowRegression for Validation 2
# 89 - WindowRegression with avg smape nan:
# Model Number: 90 of 93 with model NVAR for Validation 2
# 90 - NVAR with avg smape nan:
# Model Number: 91 of 93 with model DatepartRegression for Validation 2
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# 91 - DatepartRegression with avg smape nan:
# Model Number: 92 of 93 with model DatepartRegression for Validation 2
# 92 - DatepartRegression with avg smape nan:
# Model Number: 93 of 93 with model Ensemble for Validation 2
# 93 - Ensemble with avg smape nan:
# IOTA/BTC .predict is
#                             price
# 2020-07-30 00:01:10.647  0.000026
#                             price
# 2020-07-30 00:01:10.647  0.000026
#                             price
# 2020-07-30 00:01:10.647  0.000026
#                             price
# 2020-07-30 00:01:10.647  0.000026
# 2.643e-05
# 2.643e-05
# 0.000026430
# 0.000026430
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:330: RuntimeWarning: Mean of empty slice
#   scaler = np.nanmean(np.abs(np.diff(df_train[-100:], axis=0)), axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\autots\models\base.py:331: RuntimeWarning: All-NaN slice encountered
#   fill_val = np.nanmax(scaler)

# %%
im = float("8.99284722486562e-02")

print("%.17f" % (im))
# Out:
# 0.08992847224865620

# %%
data = pd.read_csv(r"C:\Users/Hp/Desktop/challenge/trades.csv")
  
df = pd.DataFrame(data,columns=['timestamp','price',])

df.plot(x ='timestamp', y='price', kind = 'line')



data['timestamp'] = pd.to_datetime(data['timestamp'])
#value = input("Please enter date with this form --->yyyy-mm-dd hh:mm:ss")
 
#print(f'You entered {value}')
#data = data1[~(data1['timestamp'] > value)]
data = data[~(data['timestamp'] > '2020-07-28 17:53:05')]





ask1= int(forecastnumber())
bid1= int(forecastnumber())

asksum = ask1 * 1.02
askdif = asksum - ask1
bidsum = bid1 - askdif

asksum1 = int(asksum)
bidsum1 = int(bidsum)
#print(askdif)
plt.axhline(y = asksum1, xmin=0.93, xmax=1.5, color = 'r', linestyle = '-')
plt.axhline(y = bidsum1, xmin=0.93, color = 'g', linestyle = '-')


plt.show()
